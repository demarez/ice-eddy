# %%
import matplotlib.pyplot as plt
import numpy as np
import xarray as xr
import cmocean as cm
from matplotlib import colors
from matplotlib.gridspec import GridSpec
import matplotlib.ticker as ticker
import warnings
warnings.filterwarnings('ignore')
from dask.distributed import Client
import dask
import os

client =Client()

# %%
def format_3daxis(ax,lims):
    ax.patch.set_alpha(0)
    ax.xaxis.set_major_locator(plt.MaxNLocator(3))
    ax.yaxis.set_major_locator(plt.MaxNLocator(5))
    ax.zaxis.set_major_locator(plt.MaxNLocator(3))
    
    xmin,xmax,ymin,ymax,zmin, zmax = lims
    
    ax.set(xlim=[xmin, xmax], ylim=[ymin, ymax], zlim=[zmin, zmax])

    # Plot edges
    edges_kw = dict(color='0.4', linewidth=1, zorder=1e3)

    #ax.plot([xmax, xmax], [ymin, ymax], 0, **edges_kw)
    #ax.plot([xmin, xmax], [ymin, ymin], 0, **edges_kw)
    #ax.plot([xmin, xmin], [ymin, ymax], 0, **edges_kw)
    #ax.plot([xmin, xmax], [ymax, ymax], 0, **edges_kw)
    
    ax.plot([xmax, xmax], [0, ymax], 5, **edges_kw)
    ax.plot([xmin, xmax], [0, 0], 5, **edges_kw)
    ax.plot([xmin, xmin], [0, ymax], 5, **edges_kw)
    ax.plot([xmin, xmax], [ymax, ymax], 5, **edges_kw)
    ax.plot([xmax, xmax], [0, 0], [zmin, zmax], **edges_kw)
    ax.plot([xmin, xmin], [0, 0], [zmin, zmax], **edges_kw)
    ax.plot([xmin, xmax], [0, 0], [zmin, zmin], **edges_kw)

    # Set labels and zticks
    ax.set(
        xlabel='X [km]',
        ylabel='Y [km]',
        zlabel='Depth [m]',
#         zticks=[0, -50, -100, -150],
    )

    # Set zoom and angle view
    ax.view_init(40, -60)
    ax.set_box_aspect((1,1,0.6), zoom=0.9)
    
def contour_rasterize(contour):
    for pathcoll in contour.collections:
        pathcoll.set_rasterized(True)

def axis_to_fig(axis):
    fig = axis.figure
    def transform(coord):
        return fig.transFigure.inverted().transform(
            axis.transAxes.transform(coord))
    return transform

def add_sub_axes(axis, rect,**kwargs):
    fig = axis.figure
    left, bottom, width, height = rect
    trans = axis_to_fig(axis)
    figleft, figbottom = trans((left, bottom))
    figwidth, figheight = trans([width,height]) - trans([0,0])
    return fig.add_axes([figleft, figbottom, figwidth, figheight],**kwargs)

def myfmt(x, pos):
    return '{0:.2f}'.format(x)


def remove_empty_ds(ds):
    filename = (ds.encoding['source'])
    print(ds.time)
    if len(ds.time)==0:
        print(filename)
    return ds


def load_format_data(path, var, isel, transpose=["y_afa","x_faa","z_aac"]):
    data = xr.open_mfdataset(file_paths)
    var = data[var].isel(isel).transpose(*transpose)
    return var

def format_data(data, var, isel,transpose=["y_afa","x_faa","z_aac"]):
    var = data[var].isel(isel).transpose(*transpose)
    return var

def plot3D(ax, X, Y, Z, var, kw):
    
    # Plot contour surfaces
    
    
    #half domain
    icut=int(var.shape[0]/2.)
    
    _t = ax.contourf(
        X[icut:, :, -1], Y[icut:, :, -1], var[icut:, :, -1].values,
        zdir='z', offset=0, **kw 
    )
    
    
    _r = ax.contourf(
        X[icut, :, :], var[icut, :, :].values, Z[icut, :, :],
        zdir='y', offset=0, **kw
    )
    
    C = ax.contourf(
        var[icut:, -1, :].values, Y[icut:, -1, :], Z[icut:, -1, :],
        zdir='x', offset=X.max(), **kw
    )
    
    #the full box:
    
    #_t = ax.contourf(
    #    X[:, :, -1], Y[:, :, -1], var[:, :, -1].values,
    #    zdir='z', offset=0, **kw 
    #)
    
    #_r = ax.contourf(
    #    X[0, :, :], var[0, :, :].values, Z[0, :, :],
    #    zdir='y', offset=Y.min(), **kw
    #)
    #C = ax.contourf(
    #    var[:, -1, :].values, Y[:, -1, :], Z[:, -1, :],
    #    zdir='x', offset=X.max(), **kw
    #)


   
    # Set limits of the plot from coord limits
    xmin, xmax = X.min(), X.max()
    ymin, ymax = Y.min(), Y.max()
    zmin, zmax = Z.min(), Z.max()
    
    lims = (xmin, xmax, ymin, ymax, zmin, zmax) 
    format_3daxis(ax,lims)
    
    return _t


def coriolis_frequency(latitude_degrees):
    import math
    omega = 7.2921e-5  # Earth's angular velocity (rad/s)
    phi_rad = math.radians(latitude_degrees)
    f0 = 2 * omega * math.sin(phi_rad)
    return f0

lat=-80
f0=coriolis_frequency(lat);print(f0)
# Out:
# -0.00014362633231480645

# %%
vmax=0.2
vmin=-vmax

kw = {
    'vmin': vmin,
    'vmax': vmax,
    'levels': np.linspace(vmin,vmax,50),
    'cmap': 'seismic',
    'extend':'both'
}



path_root='/data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/'

experiments= ["A-D-H-otherT2-LR_ocean"]#, "A-D-H-otherT2-LR_0mice", "A-D-H-otherT2-LR"]
data_paths = [path_root+"/RUN/"+expt for expt in experiments ]

# %%
# Create a figure with 3D ax
fig = plt.figure(figsize=(12, 6),dpi=300)
gs = GridSpec(1, 3, figure=fig)

count=0
for data_path in data_paths:
    experiment = data_path.split("/")[-1]
    vel_fields = "vel_fields*.nc"
    tracer_fields = "tracer_fields*.nc"
    vel_fields_paths = '{0}/{1}'.format(data_path, vel_fields)
    tracer_fields_paths = '{0}/{1}'.format(data_path, tracer_fields)
    
    data = xr.open_mfdataset(vel_fields_paths)# preprocess=remove_empty_ds )
    
    var = data.vort.isel(time=30).transpose("y_afa","x_faa","z_aac")
    
    Ny, Nx, Nz = var.shape
    
    X = np.ones((Ny,Nx,Nz)) * var.x_faa.values[np.newaxis,:,np.newaxis] / 1000
    Y = np.ones((Ny,Nx,Nz)) * var.y_afa.values[:, np.newaxis,np.newaxis] / 1000
    Z = np.ones((Ny,Nx,Nz)) * var.z_aac.values[np.newaxis,np.newaxis,:]
    
    

    ########################################################################
    ax1 = fig.add_subplot(gs[0, count], projection='3d', computed_zorder=False)
    plt.title(experiment + "\n 30days",fontsize=12,y=0.97)
    cbar = plot3D(ax1, X, Y, Z, var/f0, kw)
    count+=1
    
plt.subplots_adjust(hspace=0.25, wspace=0.1)
cax = fig.add_axes([0.3, 0.2, 0.43, 0.02])
cb=fig.colorbar(cbar, cax=cax, orientation='horizontal',label='$\zeta/f_0$',ticks=[vmin,0,vmax])
cb.ax.locator_params(nbins=3)
plt.show()
# Out:
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-D-H-otherT2-LR_ocean/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-D-H-otherT2-LR_ocean/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-D-H-otherT2-LR_ocean/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-D-H-otherT2-LR_ocean/vel_fields.nc: Operation not supported

# %%
# Create a figure with 3D ax
fig = plt.figure(figsize=(12, 12),dpi=300)

kw = {
    'vmin': -2e-1,
    'vmax': 2e-1,
    'levels': np.arange(-2e-1,2e-1,1e-2),
    'cmap': cm.cm.delta,
    'extend':'both'
}

for time in range(0,len(data.time)):
    print(time, end='\r')
    gs = GridSpec(1, 1, figure=fig)

    ########################################################################
    ax1 = fig.add_subplot(gs[0, 0], projection='3d')

    ax = [ax1]
    ########################################################################
    
    isel = dict(time=time)

#     ax1.text2D(0.5, 1, 'Anticyclonic', horizontalalignment='center', verticalalignment='center', transform = ax1.transAxes,fontsize=14)
#     ax4.text2D(0.5, 1, 'Cyclonic', horizontalalignment='center', verticalalignment='center', transform = ax4.transAxes,fontsize=14)

    exp_name = r"A-H5-H-LR_noATM"

    var = format_data(data, "vort", isel)/f0

    cbar = plot3D(ax[0], X, Y, Z, var, kw)

    ax[0].set_title(exp_name,y=0.98)


    cax = fig.add_axes([0.3, 0.1, 0.43, 0.02])
    cb=fig.colorbar(cbar, cax=cax, orientation='horizontal',label='$\zeta$')
    cb.ax.locator_params(nbins=3)

    # break 

    plt.subplots_adjust(hspace=0, wspace=-0.35)
    plt.savefig('./figures/animation/vorticity_Eddy_simulations_{0:03}.png'.format(time), dpi=300, bbox_inches='tight')
    plt.clf()
# Out:
# 0
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# 1
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# 2
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# 3
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# 4
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# 5
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# 6
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# 7
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# 8
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# 9
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# 10
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# 11
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# 12
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# 13
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# 14
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# 15
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# 16
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# 17
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# 18
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# 19
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# 20
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# 21
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# 22
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# 23
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# 24
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# 25
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# 26
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# 27
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# 28
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# 29
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# 30
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# 31
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# 32
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# 33
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# 34
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# 35
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# 36
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# 37
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# 38
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# 39
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# 40
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# 41
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# 42
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# 43
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# 44
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# 45
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# 46
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# 47
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# 48
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# 49
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# 50
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# 51
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# 52
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# 53
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# 54
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# 55
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# 56
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# 57
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# 58
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# 59
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# 60
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# 61
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# 62
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# 63
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# 64
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# 65
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# 66
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# 67
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# 68
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# 69
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# 70
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# 71
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# 72
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# 73
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# 74
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# 75
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# 76
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# 77
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# 78
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# 79
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# 80
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# 81
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# 82
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# 83
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# 84
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# 85
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# 86
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# 87
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# 88
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# 89
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# 90
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# 91
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V4/RUN/A-H5-H-LR_noATM/vel_fields.nc: Operation not supported

# %%
for experiment in ["A-H1-L-LR",
                   "A-H2-L-LR",
                   "A-H21-L-LR",
                   "A-H3-L-LR",
                   "A-H5-L-LR",]:
    data_path = path_root+"/RUN/"+experiment



    vel_fields = "vel_fields*.nc"
    tracer_fields = "tracer_fields*.nc"
    vel_fields_paths = '{0}/{1}'.format(data_path, vel_fields)
    tracer_fields_paths = '{0}/{1}'.format(data_path, tracer_fields)

    data = xr.open_mfdataset(vel_fields_paths)# preprocess=remove_empty_ds )

    var = data.vort.isel(time=30).transpose("yF","xF","zC")

    Ny, Nx, Nz = var.shape

    X = np.ones((Ny,Nx,Nz)) * var.xF.values[np.newaxis,:,np.newaxis] / 1000
    Y = np.ones((Ny,Nx,Nz)) * var.yF.values[:, np.newaxis,np.newaxis] / 1000
    Z = np.ones((Ny,Nx,Nz)) * var.zC.values[np.newaxis,np.newaxis,:]


    # Create a figure with 3D ax
    fig = plt.figure(figsize=(6, 6),dpi=300)
    gs = GridSpec(1, 1, figure=fig)
    ########################################################################
    ax1 = fig.add_subplot(gs[0, 0], projection='3d', computed_zorder=False)
    plt.title(experiment,fontsize=12,x=0.7,y=0.95)
    cbar = plot3D(ax1, X, Y, Z, var/f0, kw)
    plt.subplots_adjust(hspace=0.25, wspace=-0.35)
    cax = fig.add_axes([0.3, 0.1, 0.43, 0.02])
    cb=fig.colorbar(cbar, cax=cax, orientation='horizontal',label='$\zeta/f_0$',ticks=[vmin,0,vmax])
    cb.ax.locator_params(nbins=3)
    plt.show()
# Out:
# getfattr: /home/datawork-lops-osi/cdemarez/5_SECTION19/ICE-EDDY_wJ/V4/RUN/A-H1-L-LR/vel_fields.nc: Operation not supported
# getfattr: /home/datawork-lops-osi/cdemarez/5_SECTION19/ICE-EDDY_wJ/V4/RUN/A-H1-L-LR/vel_fields.nc: Operation not supported
# getfattr: /home/datawork-lops-osi/cdemarez/5_SECTION19/ICE-EDDY_wJ/V4/RUN/A-H1-L-LR/vel_fields.nc: Operation not supported
# getfattr: /home/datawork-lops-osi/cdemarez/5_SECTION19/ICE-EDDY_wJ/V4/RUN/A-H2-L-LR/vel_fields.nc: Operation not supported
# getfattr: /home/datawork-lops-osi/cdemarez/5_SECTION19/ICE-EDDY_wJ/V4/RUN/A-H2-L-LR/vel_fields.nc: Operation not supported
# getfattr: /home/datawork-lops-osi/cdemarez/5_SECTION19/ICE-EDDY_wJ/V4/RUN/A-H2-L-LR/vel_fields.nc: Operation not supported
# getfattr: /home/datawork-lops-osi/cdemarez/5_SECTION19/ICE-EDDY_wJ/V4/RUN/A-H21-L-LR/vel_fields.nc: Operation not supported
# getfattr: /home/datawork-lops-osi/cdemarez/5_SECTION19/ICE-EDDY_wJ/V4/RUN/A-H21-L-LR/vel_fields.nc: Operation not supported
# getfattr: /home/datawork-lops-osi/cdemarez/5_SECTION19/ICE-EDDY_wJ/V4/RUN/A-H21-L-LR/vel_fields.nc: Operation not supported
# getfattr: /home/datawork-lops-osi/cdemarez/5_SECTION19/ICE-EDDY_wJ/V4/RUN/A-H3-L-LR/vel_fields.nc: Operation not supported
# getfattr: /home/datawork-lops-osi/cdemarez/5_SECTION19/ICE-EDDY_wJ/V4/RUN/A-H3-L-LR/vel_fields.nc: Operation not supported
# getfattr: /home/datawork-lops-osi/cdemarez/5_SECTION19/ICE-EDDY_wJ/V4/RUN/A-H3-L-LR/vel_fields.nc: Operation not supported
# getfattr: /home/datawork-lops-osi/cdemarez/5_SECTION19/ICE-EDDY_wJ/V4/RUN/A-H5-L-LR/vel_fields.nc: Operation not supported
# getfattr: /home/datawork-lops-osi/cdemarez/5_SECTION19/ICE-EDDY_wJ/V4/RUN/A-H5-L-LR/vel_fields.nc: Operation not supported
# getfattr: /home/datawork-lops-osi/cdemarez/5_SECTION19/ICE-EDDY_wJ/V4/RUN/A-H5-L-LR/vel_fields.nc: Operation not supported

# %%
vmax=0.1
vmin=-vmax

kw = {
    'vmin': vmin,
    'vmax': vmax,
    'levels': np.linspace(vmin,vmax,50),
    'cmap': 'seismic',
    'extend':'both'
}



path_root='/home/datawork-lops-osi/cdemarez/5_SECTION19/ICE-EDDY_wJ/V4/'

experiment="C-H6-H-LR"
data_path = path_root+"/RUN/"+experiment



vel_fields = "vel_fields*.nc"
tracer_fields = "tracer_fields*.nc"
vel_fields_paths = '{0}/{1}'.format(data_path, vel_fields)
tracer_fields_paths = '{0}/{1}'.format(data_path, tracer_fields)

data = xr.open_mfdataset(vel_fields_paths)# preprocess=remove_empty_ds )

var = data.vort.isel(time=7).transpose("yF","xF","zC")

Ny, Nx, Nz = var.shape

X = np.ones((Ny,Nx,Nz)) * var.xF.values[np.newaxis,:,np.newaxis] / 1000
Y = np.ones((Ny,Nx,Nz)) * var.yF.values[:, np.newaxis,np.newaxis] / 1000
Z = np.ones((Ny,Nx,Nz)) * var.zC.values[np.newaxis,np.newaxis,:]


# Create a figure with 3D ax
fig = plt.figure(figsize=(6, 6),dpi=300)
gs = GridSpec(1, 1, figure=fig)
########################################################################
ax1 = fig.add_subplot(gs[0, 0], projection='3d', computed_zorder=False)
plt.title(experiment,fontsize=12,x=0.7,y=0.95)
cbar = plot3D(ax1, X, Y, Z, var/f0, kw)
plt.subplots_adjust(hspace=0.25, wspace=-0.35)
cax = fig.add_axes([0.3, 0.1, 0.43, 0.02])
cb=fig.colorbar(cbar, cax=cax, orientation='horizontal',label='$\zeta/f_0$',ticks=[vmin,0,vmax])
cb.ax.locator_params(nbins=3)
plt.show()
# Out:
# getfattr: /home/datawork-lops-osi/cdemarez/5_SECTION19/ICE-EDDY_wJ/V4/RUN/C-H6-H-LR/vel_fields.nc: Operation not supported
# getfattr: /home/datawork-lops-osi/cdemarez/5_SECTION19/ICE-EDDY_wJ/V4/RUN/C-H6-H-LR/vel_fields.nc: Operation not supported
# getfattr: /home/datawork-lops-osi/cdemarez/5_SECTION19/ICE-EDDY_wJ/V4/RUN/C-H6-H-LR/vel_fields.nc: Operation not supported
# getfattr: /home/datawork-lops-osi/cdemarez/5_SECTION19/ICE-EDDY_wJ/V4/RUN/C-H6-H-LR/vel_fields.nc: Operation not supported

# %%
# data_path = "/data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-4-noise10percent_new_strat_BiH"

# lat=80
# f0=coriolis_frequency(lat);print(f0)

# vel_fields = "vel_fields*.nc"
# tracer_fields = "tracer_fields*.nc"
# vel_fields_paths = '{0}/{1}'.format(data_path, vel_fields)
# tracer_fields_paths = '{0}/{1}'.format(data_path, tracer_fields)

# data = xr.open_mfdataset(vel_fields_paths)# preprocess=remove_empty_ds )
# Out:
# Data variables:
#     B        (time, zC, yC, xC) float64 221MB dask.array<chunksize=(1, 30, 100, 100), meta=np.ndarray>
#     S        (time, zC, yC, xC) float64 221MB dask.array<chunksize=(1, 30, 100, 100), meta=np.ndarray>
#     T        (time, zC, yC, xC) float64 221MB dask.array<chunksize=(1, 30, 100, 100), meta=np.ndarray>
# getfattr: /home/datawork-lops-osi/cdemarez/5_SECTION19/ICE-EDDY_wJ/V4/RUN/C-H6-H-LR/tracer_fields.nc: Operation not supported

# %%
var = data.B.isel(time=0).transpose("yC","xC","zC")
plt.pcolormesh(var[:,50,:].T,cmap='nipy_spectral')
plt.colorbar()
# Out:
# getfattr: /home/datawork-lops-osi/cdemarez/5_SECTION19/ICE-EDDY_wJ/V4/RUN/C-H6-H-LR/tracer_fields.nc: Operation not supported

# %%
plt.plot(var[0,0,:],Z[0,0,:])
plt.plot(var[50,50,:],Z[50,50,:])
plt.show()
# Out:
# getfattr: /home/datawork-lops-osi/cdemarez/5_SECTION19/ICE-EDDY_wJ/V4/RUN/C-H6-H-LR/tracer_fields.nc: Operation not supported

# %%
data = xr.open_mfdataset(vel_fields_paths)# preprocess=remove_empty_ds )

print(data.data_vars)
# Out:
# Data variables:
#     vort     (time, zC, yF, xF) float64 367MB dask.array<chunksize=(1, 30, 101, 101), meta=np.ndarray>
#     U        (time, zC, yC, xF) float64 364MB dask.array<chunksize=(1, 30, 100, 101), meta=np.ndarray>
#     V        (time, zC, yF, xC) float64 364MB dask.array<chunksize=(1, 30, 101, 100), meta=np.ndarray>
# getfattr: /home/datawork-lops-osi/cdemarez/5_SECTION19/ICE-EDDY_wJ/V4/RUN/A-H3-nonoise-H-LR/vel_fields.nc: Operation not supported

# %%
var = data.U.isel(time=20).transpose("yC","xF","zC")
plt.pcolormesh(var[:,50,:].T,cmap='nipy_spectral')
plt.colorbar()
# Out:
# getfattr: /home/datawork-lops-osi/cdemarez/5_SECTION19/ICE-EDDY_wJ/V4/RUN/A-H3-nonoise-H-LR/vel_fields.nc: Operation not supported

# %%
data = xr.open_mfdataset(tracer_fields_paths)# preprocess=remove_empty_ds )

print(data.data_vars)
# Out:
# Data variables:
#     B        (time, zC, yC, xC) float64 437MB dask.array<chunksize=(1, 30, 100, 100), meta=np.ndarray>
#     S        (time, zC, yC, xC) float64 437MB dask.array<chunksize=(1, 30, 100, 100), meta=np.ndarray>
#     T        (time, zC, yC, xC) float64 437MB dask.array<chunksize=(1, 30, 100, 100), meta=np.ndarray>
# getfattr: /home/datawork-lops-osi/cdemarez/5_SECTION19/ICE-EDDY_wJ/V2/RUN/C-5-LR/tracer_fields.nc: Operation not supported

# %%
vmax=-0.05
vmin=-0.085

kw = {
    'vmin': vmin,
    'vmax': vmax,
    'levels': np.linspace(vmin,vmax,50),
    'cmap': 'nipy_spectral',
    'extend':'both'
}


var = data.B.isel(time=20).transpose("yC","xC","zC")

# Ny, Nx, Nz = var.shape

# X = np.ones((Ny,Nx,Nz)) * var.xF.values[np.newaxis,:,np.newaxis] / 1000
# Y = np.ones((Ny,Nx,Nz)) * var.yF.values[:, np.newaxis,np.newaxis] / 1000
# Z = np.ones((Ny,Nx,Nz)) * var.zC.values[np.newaxis,np.newaxis,:]

# # X = np.ones((Ny,Nx,Nz)) * var.x_faa.values[np.newaxis,:,np.newaxis] / 1000
# # Y = np.ones((Ny,Nx,Nz)) * var.y_afa.values[:, np.newaxis,np.newaxis] / 1000
# # Z = np.ones((Ny,Nx,Nz)) * var.z_aac.values[np.newaxis,np.newaxis,:]


# # Create a figure with 3D ax
# fig = plt.figure(figsize=(6, 6),dpi=300)
# gs = GridSpec(1, 1, figure=fig)
# ########################################################################
# ax1 = fig.add_subplot(gs[0, 0], projection='3d', computed_zorder=False)
# cbar = plot3D(ax1, X, Y, Z, var/f0, kw)
# plt.subplots_adjust(hspace=0.25, wspace=-0.35)
# cax = fig.add_axes([0.3, 0.1, 0.43, 0.02])
# cb=fig.colorbar(cbar, cax=cax, orientation='horizontal',label='$\zeta/f_0$',ticks=[vmin,0,vmax])
# cb.ax.locator_params(nbins=3)
# plt.show()
# Out:
# getfattr: /home/datawork-lops-osi/cdemarez/5_SECTION19/ICE-EDDY_wJ/V2/RUN/C-5-LR/tracer_fields.nc: Operation not supported
# getfattr: /home/datawork-lops-osi/cdemarez/5_SECTION19/ICE-EDDY_wJ/V2/RUN/C-5-LR/tracer_fields.nc: Operation not supported
# getfattr: /home/datawork-lops-osi/cdemarez/5_SECTION19/ICE-EDDY_wJ/V2/RUN/C-5-LR/tracer_fields.nc: Operation not supported

# %%
# Create a figure with 3D ax
fig = plt.figure(figsize=(12, 12),dpi=300)

kw = {
    'vmin': -3e-1,
    'vmax': 3e-1,
    'levels': np.arange(-3e-1,3e-1,1e-1),
    'cmap': cm.cm.delta,
    'extend':'both'
}

for time in range(0,len(data.time)):
    print(time, end='\r')
    gs = GridSpec(1, 1, figure=fig)

    ########################################################################
    ax1 = fig.add_subplot(gs[0, 0], projection='3d')

    ax = [ax1]
    ########################################################################
    
    isel = dict(time=time)

#     ax1.text2D(0.5, 1, 'Anticyclonic', horizontalalignment='center', verticalalignment='center', transform = ax1.transAxes,fontsize=14)
#     ax4.text2D(0.5, 1, 'Cyclonic', horizontalalignment='center', verticalalignment='center', transform = ax4.transAxes,fontsize=14)

    exp_name = r"Cyclonic"

    var = format_data(data, "vort", isel)/f0

    cbar = plot3D(ax[0], X, Y, Z, var, kw)

    ax[0].set_title(exp_name,y=0.98)


    cax = fig.add_axes([0.3, 0.1, 0.43, 0.02])
    cb=fig.colorbar(cbar, cax=cax, orientation='horizontal',label='$\zeta$')
    cb.ax.locator_params(nbins=3)

    # break 

    plt.subplots_adjust(hspace=0, wspace=-0.35)
    plt.savefig('./figures/animation/vorticity_Eddy_simulations_{0:03}.png'.format(time), dpi=300, bbox_inches='tight')
    plt.clf()
# Out:
# 0
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# 1
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# 2
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# 3
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# 4
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# 5
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# 6
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# 7
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# 8
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# 9
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# 10
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# 11
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# 12
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# 13
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# 14
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# 15
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# 16
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# ...
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# 177
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# 178
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# 179
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# 180
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# 181
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported
# getfattr: /data/hpcflash/users/josnez/Oceananigans/ICE-EDDY_wJ/V0/RUN/C-8-noise10percent_only_salt_BiH/vel_fields.nc: Operation not supported

# %% [markdown]
# ## Salinity

# %%
data = xr.open_mfdataset(tracer_fields_paths)# preprocess=remove_empty_ds )
# Out:
# /tmp/ipykernel_1518605/3718822677.py:1: FutureWarning: In a future version of xarray decode_timedelta will default to False rather than None. To silence this warning, set decode_timedelta to True, False, or a 'CFTimedeltaCoder' instance.
#   data = xr.open_mfdataset(tracer_fields_paths)# preprocess=remove_empty_ds )

# %%
var = data.S.isel(time=-1).transpose("yC","xC","zC")
var.min().compute(),var.max().compute()
# Out:
# (<xarray.DataArray 'S' ()> Size: 8B
#  array(31.58930317)
#  Coordinates:
#      time     timedelta64[ns] 8B 60 days,
#  <xarray.DataArray 'S' ()> Size: 8B
#  array(34.90723718)
#  Coordinates:
#      time     timedelta64[ns] 8B 60 days)

# %%
Ny, Nx, Nz = var.shape

X = np.ones((Ny,Nx,Nz)) * var.xC.values[np.newaxis,:,np.newaxis] / 1000
Y = np.ones((Ny,Nx,Nz)) * var.yC.values[:, np.newaxis,np.newaxis] / 1000
Z = np.ones((Ny,Nx,Nz)) * var.zC.values[np.newaxis,np.newaxis,:]

# %%
# Create a figure with 3D ax
fig = plt.figure(figsize=(6, 6),dpi=300)


gs = GridSpec(1, 1, figure=fig)

########################################################################
ax1 = fig.add_subplot(gs[0, 0], projection='3d', computed_zorder=False)


kw = {
    'vmin': 31.5,
    'vmax': 35,
    'levels': np.arange(31.5,35,0.05),
    'cmap': cm.cm.haline,
    'extend':'both'
}

cbar = plot3D(ax1, X/1000, Y/1000, Z, var, kw)

plt.subplots_adjust(hspace=0.25, wspace=-0.35)


cax = fig.add_axes([0.3, 0.1, 0.43, 0.02])
cb=fig.colorbar(cbar, cax=cax, orientation='horizontal',label='$psu$')
cb.ax.locator_params(nbins=5)

# %%
# Create a figure with 3D ax
fig = plt.figure(figsize=(12, 12),dpi=300)

kw = {
    'vmin': 31.5,
    'vmax': 35,
    'levels': np.arange(31.5,35,0.05),
    'cmap': cm.cm.haline,
    'extend':'both'
}

for time in range(0,len(data.time)):
    print(time, end='\r')
    gs = GridSpec(1, 1, figure=fig)

    ########################################################################
    ax1 = fig.add_subplot(gs[0, 0], projection='3d')

    ax = [ax1]
    ########################################################################
    
    isel = dict(time=time)

#     ax1.text2D(0.5, 1, 'Anticyclonic', horizontalalignment='center', verticalalignment='center', transform = ax1.transAxes,fontsize=14)
#     ax4.text2D(0.5, 1, 'Cyclonic', horizontalalignment='center', verticalalignment='center', transform = ax4.transAxes,fontsize=14)

    exp_name = r"$\psi$ = 5"

    var = format_data(data, "S", isel,transpose=["yC","xC","zC"])
    var = var
    
    cbar = plot3D(ax[0], X, Y, Z, var, kw)

    ax[0].set_title(exp_name,y=0.98)


    cax = fig.add_axes([0.3, 0.1, 0.43, 0.02])
    cb=fig.colorbar(cbar, cax=cax, orientation='horizontal',label='$psu$')
    cb.ax.locator_params(nbins=5)

    # break 

    plt.subplots_adjust(hspace=0, wspace=-0.35)
    plt.savefig('./figures/animation/salinity_Eddy_simulations_{0:03}.png'.format(time), dpi=300, bbox_inches='tight')
    plt.clf()
# Out:
# 120

# %%
# !pwd
# Out:
# /data/hpcdata/users/josnez/notebooks/Single_eddy
